# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/home/anjana/study/case_study/home/notebooks/Investment_Preprocessed.csv")
df
# Out:
#        age  duration  emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 0       44       210           1.4          93.444          -36.1      4.963
# 1       53       138          -0.1          93.200          -42.0      4.021
# 2       28       339          -1.7          94.055          -39.8      0.729
# 3       39       185          -1.8          93.075          -47.1      1.405
# 4       55       137          -2.9          92.201          -31.4      0.869
# ...    ...       ...           ...             ...            ...        ...
# 40311   24       118          -1.8          92.893          -46.2      1.266
# 40312   59       222           1.4          94.465          -41.8      4.866
# 40313   31       196           1.1          93.994          -36.4      4.860
# 40314   42        62           1.1          93.994          -36.4      4.857
# 40315   25       112           1.1          93.994          -36.4      4.859
#
#        nr_employed  Invested  job_blue-collar  job_entrepreneur  ...  \
# 0           5228.1         0             True             False  ...
# 1           5195.8         0            False             False  ...
# 2           4991.6         1            False             False  ...
# 3           5099.1         0            False             False  ...
# 4           5076.2         1            False             False  ...
# ...            ...       ...              ...               ...  ...
# 40311       5099.1         0            False             False  ...
# 40312       5228.1         0            False             False  ...
# 40313       5191.0         0            False             False  ...
# 40314       5191.0         0            False             False  ...
# 40315       5191.0         0            False             False  ...
#
#        month_may  month_nov  month_oct  month_sep  day_of_week_mon  \
# 0          False      False      False      False            False
# 1          False       True      False      False            False
# 2          False      False      False      False            False
# 3          False      False      False      False            False
# 4          False      False      False      False            False
# ...          ...        ...        ...        ...              ...
# 40311       True      False      False      False            False
# 40312      False      False      False      False            False
# 40313       True      False      False      False            False
# 40314       True      False      False      False            False
# 40315       True      False      False      False            False
#
#        day_of_week_thu  day_of_week_tue  day_of_week_wed  \
# 0                 True            False            False
# 1                False            False            False
# 2                 True            False            False
# 3                False            False            False
# 4                False            False            False
# ...                ...              ...              ...
# 40311             True            False            False
# 40312             True            False            False
# 40313             True            False            False
# 40314            False            False             True
# 40315            False            False            False
#
#        poutcome_nonexistent  poutcome_success
# 0                      True             False
# 1                      True             False
# 2                     False              True
# 3                      True             False
# 4                     False              True
# ...                     ...               ...
# 40311                 False             False
# 40312                  True             False
# 40313                  True             False
# 40314                  True             False
# 40315                  True             False
#
# [40316 rows x 49 columns]

# %%
x=df.drop('Invested',axis=1)
y=df['Invested']
print(x.shape, y.shape)
# Out:
# (40316, 48) (40316,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=999)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (28221, 48) (12095, 48) (28221,) (12095,)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9179826374534932

# %%
from joblib import dump

# %%
dump(model, '/home/anjana/study/case_study/home/
